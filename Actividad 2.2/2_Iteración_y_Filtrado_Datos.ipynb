# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/TI2001B-2023/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#GOOGLE COLAB
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %% [markdown]
# CARGA DE ARCHIVO XLSX

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('los-angeles.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43932 entries, 0 to 43931
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              43932 non-null  int64
#  1   name                            43932 non-null  str
#  2   host_id                         43751 non-null  float64
#  3   host_profile_id                 43537 non-null  float64
#  4   host_name                       43548 non-null  str
#  5   neighbourhood_group             43932 non-null  str
#  6   neighbourhood                   43932 non-null  str
#  7   latitude                        43932 non-null  float64
#  8   longitude                       43932 non-null  float64
#  9   room_type                       43932 non-null  str
#  10  price                           38362 non-null  float64
#  11  minimum_nights                  43921 non-null  float64
# ...

# %%
inciso1=df[(df["CVE_CLPV"] >= 1000) & (df["CVE_CLPV"] <= 2000)]
inciso1

# %%
inciso2=df[~(df["CVE_VEND"].isin([5, 4]))]
inciso2

# %%
inciso3=df[(df["FECHA_ENT"] == "2022-02-28 00:00:00")]
inciso3

# %%
inciso4=df[(df["CAN_TOT"] > 5951.7) | (df["STATUS"] == "E")]
inciso4

# %%
inciso5=df.iloc[:, [1] + [7] + [8] + [10]]
inciso5

# %%
inciso6=df.iloc[list(range(7001, 8000)), :]
inciso6

# %%
inciso_a=df["host_name"].drop_duplicates().head(5)
inciso_a

# %%
# No existe columna de "host_since" en mi lista de Los Angeles. Voy a usar "last_review" después de 2020
inciso_b=df[df["last_review"] > "2020-12-31"]
inciso_b

# %%
# Inciso C: No existe columna de "host_response_time" en mi lista de Los Angeles.

# %%
inciso_d=df[200::200]
inciso_d

# %%
inciso_e=df[(df["room_type"] == "Entire home/apt") | (df["room_type"] == "Private room")]
inciso_e

# %%
# Inciso F: No existe una columna que me indique cuantas camas hay en mis datos.

# %%
# Inciso G: No existe una columna que me indique si un socio es "superhost".

# %%
inciso_h=df.iloc[: , 1::2]
inciso_h

# %%
df1= pd.read_csv('los-angeles.csv')
df1
# Out:
#                         id                                               name  \
# 0                     2708  Run Runyon, Beaut Furn Mirror Mini-Suit w/ Fir...
# 1                     2732                              Zen Life at the Beach
# 2                     6033                           Poolside Serenity Studio
# 3                     6931  RUN Runyon, Beau Furn Rms Terrace Hollyw Hill ...
# 4                     7874      HD Wi-Fi E Bellflower Cerritos Lakewood LB LA
# ...                    ...                                                ...
# 43927  1707678777570851520  The French Lime Pool House - Sleeps 8 - Air ho...
# 43928  1707701464310658544                   Hollywood City Views The Godfrey
# 43929  1707712658970417218             Spacious Waterfront 3BR Marina Retreat
# 43930  1707714248958928308                      Zen in Hollywood Walk of Fame
# 43931  1707753561170835767                                   West Hills Oasis
#
# ...

# %%
inciso7=df1.loc[[1, 2], ["FECHAELAB"]]
inciso7
# Out:
#                         FECHAELAB
# CVE_VEND
# 1.0       2019-09-03 08:58:42.000
# 1.0       2019-09-03 09:55:14.000
# 1.0       2019-09-03 13:25:33.000
# 1.0       2019-09-03 13:33:23.000
# 1.0       2019-09-04 09:15:12.000
# ...                           ...
# 2.0       2023-03-06 16:09:39.013
# 2.0       2023-03-06 16:38:42.933
# 2.0       2023-03-06 17:02:33.390
# 2.0       2023-03-07 12:43:49.567
# 2.0       2023-03-07 12:45:58.407
#
# [8665 rows x 1 columns]

# %%
#Verificamos información del DataFrame
df.info()
df.head(5)

# %% [markdown]
# ITERACIÓN

# %% [markdown]
# **Iterar columnas directamente del dataframe**

# %%
# Iterar sobre la columna 'nombre'
for nombre in df['NOMBRE']:
    print(nombre)

# %% [markdown]
# ***USANDO NUMPY***

# %% [markdown]
# **Iterar columnas tipo STRING**

# %%
# Iterar sobre una columna tipo string: 'NOMBRE' con Numpy
nombres = df['NOMBRE'].to_numpy() #Primero convertimos la columna en un array

# Iterar sobre el array
for nombre in np.nditer(nombres, flags=['refs_ok']): #Usamos flags=['refs_ok'] si la columna contiene strings (objetos) en lugar de números
    print(nombre.item())  # item() lo convierte a string nativo de Python

# %% [markdown]
# **Iterar columnas tipo NUMÉRICO**

# %%
# Iterar sobre una columna tipo numérico: 'MONTO ADEUDADO' con Numpy
monto_adeudado = df['MONTO ADEUDADO'].to_numpy() # Convertir la columna 'MONTO ADEUDADO' a array de NumPy

# Iterar sobre el array
for monto_adeudado in np.nditer(monto_adeudado):
    print(monto_adeudado)  # monto_adeudado es directamente un número (int o float)

# %% [markdown]
# **Iterar Filas**

# %%
# Iterar sobre cada fila del dataframe
for index, row in df.iterrows():
    print(f"Fila {index}:")
    print(f"NOMBRE: {row['NOMBRE']}")
    print(f"FECHA DE VENCIMIENTO: {row['FECHA_VENCIMIENTO']}")
    print("-----")

# %% [markdown]
# **OPERACIONES FUNDAMENTALES**

# %%
#Convertir cada nombre a mayúsculas
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(nombre.upper())

# %%
#Convertir cada nombre a minúsculas
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(nombre.lower())

# %%
#Convertir la primera letra del registro en mayúscula
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(nombre.capitalize())

# %%
#Convertir la primera letra de cada palabra en mayúscula
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(nombre.title())

# %%
#Contar cuántas letras tiene cada nombre
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(nombre, "tiene", len(nombre), "letras")

# %%
#Mostrar solamente los nombres que tienen menos de 15 letras
for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    
    if len(nombre) < 15:
        print(nombre)

# %%
#Crear un saludo para cada nombre
def saludar(nombre):
    return "Hola " + nombre + ", bienvenid@!"

for nombre in np.nditer(nombres, flags=['refs_ok']):
    nombre = nombre.item()
    print(saludar(nombre))

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE"] == "INDUSTRIAS LANCERMEX"]
filtro1

# %%
#Filtro por filas
#filtro2= df.iloc[3:11,: ]           #Filas consecutivas
#filtro2=df.iloc[ [8, 24, 100] , : ]  #Filas no consecutivas
filtro2= df.iloc[ [0] + list(range(10, 14)) + [50] , : ]  #Filas combinadas
filtro2

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 0:3]       #Columnas consecutivas
#filtro3=df.iloc[ : , [1,4,6]]  #Columnas no consecutivas
filtro3= df.iloc[ :, [0] + list(range(1, 4)) + [5] ]  #Filas combinadas
filtro3

# %%
#GOOGLE COLAB
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()

# %%
df1= pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx', index_col=1)
df1

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["HELVEX","DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO"]]
filtro4

# %%
#Filtro por cabecera
filtro5=df.head()
filtro5

# %%
#Filtro por cola
filtro5=df.tail()
filtro5

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
filtro6=df[df["MONTO ADEUDADO"] == 1000]
filtro6

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y (&)
filtro7=df[(df["MONTO ADEUDADO"] < 6000) & (df["FECHA_FACTURA"] == "2023-03-14")]
filtro7

# %%
#Filtro o (|)
filtro8=df[(df["MONTO ADEUDADO"] < 6000) | (df["FECHA_FACTURA"] == "2023-03-14")]
filtro8

# %%
#Filtro not (~)
filtro9=df[~(df["MONTO ADEUDADO"] >= 6000)]
filtro9

# %%
#Convertir archivo filtrado a CSV
inciso_h.to_csv("Inciso_h.csv")

# %%
#GOOGLE COLAB
#descardar archivo filtrado en csv
from google.colab import files


files.download("Entregable1.csv")
